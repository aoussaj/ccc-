# %%
#Reducedtwo
D0 =[0,0.15236,0.29482,0.26747,1.961]
D1 = [2.5672,2.4472,2.8503,2.7901,4.5304]
D2 =[2.7728	,2.9451	,2.4569	,3.1346,4.6598]
D4=	[2.9589,3.1262,3.1163,3.3219,1.23429]
D9=	[3.4704,3.5637,3.9488,3.2418,4.9176]
x_labels =[r'$\mathrm{S_{0}}$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow \Sigma_{\mathrm{I}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$']
#ReducedOH
D0 = [0,0.13798,0.26338,1.95113,0.21446]
D1=	[2.5831,2.4794,2.8692,2.7898,4.5139]
D2=[2.8182,2.9603,2.4984,3.0978,4.7393]
D3 =[2.9302,3.0473,3.0682,1.21604,3.3681]
D6=[3.5007,3.6178,3.9055,5.6363,3.3039]
x_labels =[r'$\mathrm{S_{0}}$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow \Sigma_{\mathrm{I}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$']
#ReducedNO2
D0=(0,0.168,0.33,1.68,2.01)
D1=(1.3263,1.5482,1.4038, 3.3142, 3.2270)
D2=(2.3115, 2.1551,2.7917, 4.1797, 4.6812)
D3=(2.6549, 3.0052,2.2790, 3.7286,4.4898)
D4=(3.1698,3.5115,3.2453,4.8154,1.4670)
D6=(3.2806,3.5959,3.3541,1.117,3.2723)
x_labels =[r'$\mathrm{S_{0}}$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow \Sigma_{\mathrm{I}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow \Sigma_{\mathrm{I}}^*)$']
#ReducedNO2DOUBLEhybrid
D0=	(0,0.34	,0.34,1.05,1.05)
D1=	(1.90875,2.073,2.16006,4.962,3.112)
D2=	(2.45918,2.433,2.90435,2.864,3.59)
D3=	(3.56987,3.597,3.02376,5.134,4.482)
D4=	(3.57655,4.137,3.79277,4.43372,3.649)
D6=	(3.61446,4.271,3.91377,4.639,2.4)
x_labels =[r'$\mathrm{S_{0}}$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow \Sigma_{\mathrm{I}}^*)$',r'$\mathrm{S}(\pi_{\mathrm{BOD}} \rightarrow \Sigma_{\mathrm{I}}^*)$']

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
# Create subplots
fig, ((ax1, ax3), (ax2, ax4)) = plt.subplots(2, 2, figsize=(10, 9),dpi=600)
# First subplot
#Reducedtwo
x1 = [1, 2, 3, 4, 5]
D0 =[0,0.15236,0.29482,1.961,0.26747]
D1 = [2.5672,2.4472,2.8503,2.7901,4.5304]
D2 =[2.7728	,2.9451	,2.4569	,3.1346,4.6598]
D4=	[2.9589,3.1262,3.1163,1.23429,3.3219]
D9=	[3.4704,3.5637,3.9488,4.9176,3.2418]
ax1.plot(x1,D0, linestyle='dashed', marker='_', markersize=30, color='orange', linewidth=0.4)
ax1.plot(x1,D1, linestyle='dashed', marker='_', markersize=30, color='black', linewidth=0.4)
ax1.plot(x1,D2, linestyle='dashed', marker='_', markersize=30, color='blue', linewidth=0.4)
ax1.plot(x1,D4, linestyle='dashed', marker='_', markersize=30, color='green', linewidth=0.4)
ax1.plot(x1, D9, linestyle='dashed', marker='_', markersize=30, color='black', linewidth=0.4)
ax1.set_xticks(x1)
x_labels =[r'$\mathrm{D_{0}}$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow \sigma_I^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$']
ax1.set_xticklabels(x_labels,fontweight='bold', fontsize=15, rotation=15)
my_colors = ['orange', 'black', 'blue', 'green', 'black']
for ticklabel, tickcolor in zip(ax1.get_xticklabels(), my_colors):
    ticklabel.set_color(tickcolor)
ax1.set_xticks(x1)
# Define font properties dictionary
font_properties = {'weight': 'bold', 'size': 12}
# Apply x-axis tick labels with the custom font properties
ax1.set_xticklabels(x_labels, rotation=15, fontdict=font_properties) 
ax1.set_xlabel("BOD-Ph(TDA-DFT)_MN15",fontsize=10, fontweight='bold')
ax1.set_ylabel("Energie(eV)",fontweight='bold')
ax1.tick_params(axis='x', rotation=15, color='black',labelsize=12)
for x_labels in ax1.get_xticklabels():
    x_labels.set_ha('right')
    x_labels.set_rotation_mode('anchor')
ax1.set_ylim( -0.2,6)
ax1.set_yticks(np.arange(0, 6, 1))
ax1.tick_params(axis='y', labelsize=9)
#ReducedOH
x2 = [1, 2, 3, 4, 5]
D0 = [0,0.13798,0.26338,1.95113,0.21446]
D1=	[2.5831,2.4794,2.8692,2.7898,4.5139]
D2=[2.8182,2.9603,2.4984,3.0978,4.7393]
D3 =[2.9302,3.0473,3.0682,1.21604,3.3681]
D6=[3.5007,3.6178,3.9055,5.6363,3.3039]
ax2.plot(x2, D0, linestyle='dashed', marker='_', markersize=30, color='orange', linewidth=0.4)
ax2.plot(x2, D1, linestyle='dashed', marker='_', markersize=30, color='black', linewidth=0.4)
ax2.plot(x2,D2, linestyle='dashed', marker='_', markersize=30, color='blue', linewidth=0.4)
ax2.plot(x2,D3, linestyle='dashed', marker='_', markersize=30, color='green', linewidth=0.4)
ax2.plot(x2,D6, linestyle='dashed', marker='_', markersize=30, color='black', linewidth=0.4)
ax2.set_xticks(x2)
x_labels2 =[r'$\mathrm{D_{0}}$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow \sigma_{\mathrm{I}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$']
ax2.set_xticklabels(x_labels2, fontsize=12, fontweight='bold', rotation=15)
my_colors2 = ['orange', 'black','blue','green','black']
for ticklabel, tickcolor in zip(ax2.get_xticklabels(), my_colors2):
    ticklabel.set_color(tickcolor)
ax2.set_xticks(x2)
# Define font properties dictionary
font_properties = {'weight': 'bold', 'size': 12}
# Apply x-axis tick labels with the custom font properties
ax2.set_xticklabels(x_labels2, rotation=15, fontdict=font_properties) 
ax2.set_xlabel("BOD-PhOH(TDA-DFT)_MN15",fontsize=10, fontweight='bold')
ax2.set_ylabel("Energie(eV)",fontweight='bold')
ax2.tick_params(axis='x', rotation=15, color='black')
for x_labels2 in ax2.get_xticklabels():
    x_labels2.set_ha('right')
    x_labels2.set_rotation_mode('anchor')
ax2.set_ylim( -0.2,6)
ax2.set_yticks(np.arange(0, 6, 1))
ax2.tick_params(axis='y', labelsize=9)
#ReducedNO2
x3 = [1, 2, 3, 4, 5]
D0=(0,0.168,0.33,1.68,2.01)
D1=(1.3263,1.5482,1.4038, 3.3142, 3.2270)
D2=(2.3115, 2.1551,2.7917, 4.1797, 4.6812)
D3=(2.6549, 3.0052,2.2790, 3.7286,4.4898)
D4=(3.1698,3.5115,3.2453,4.8154,1.4670)
D6=(3.2806,3.5959,3.3541,1.117,3.2723)
ax3.plot(x3,D0, linestyle='dashed', marker='_', markersize=30, color='orange', linewidth=0.4)
ax3.plot(x3,D1, linestyle='dashed', marker='_', markersize=30, color='blue', linewidth=0.4)
ax3.plot(x3,D2, linestyle='dashed', marker='_', markersize=30, color='black', linewidth=0.4)
ax3.plot(x3,D3, linestyle='dashed', marker='_', markersize=30, color='blue', linewidth=0.4)
ax3.plot(x3,D4, linestyle='dashed', marker='_', markersize=30, color='green', linewidth=0.4)
ax3.plot(x3,D6, linestyle='dashed', marker='_', markersize=30, color='green', linewidth=0.4)
ax3.set_xticks(x3)
x_labels3 =[r'$\mathrm{D_{0}}$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow \sigma_{\mathrm{I}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow \sigma_{\mathrm{I}}^*)$']
ax3.set_xticklabels(x_labels3, fontsize=12, fontweight='bold', rotation=15)
my_colors3 = ['orange','black','blue',"green","green"]
for ticklabel, tickcolor in zip(ax3.get_xticklabels(), my_colors3):
    ticklabel.set_color(tickcolor)
ax3.set_xlabel('BOD-Ph'+ r'$\mathbf{NO_2}$'+'(TDDFT)_MN15',fontsize=10, fontweight='bold')
ax3.set_ylabel("Energie(eV)",fontweight='bold')
ax3.tick_params(axis='x', rotation=15, color='black')
for x_labels3 in ax3.get_xticklabels():
    x_labels3.set_ha('right')
    x_labels3.set_rotation_mode('anchor')
ax3.tick_params(axis='y',labelsize=12)
ax3.set_ylim( -0.2,6)
ax3.set_yticks(np.arange(0, 6, 1))
ax3.tick_params(axis='y', labelsize=9)
#ReducedNO2DOUBLEhybrid
x4 = [1, 2, 3, 4]
D0=	(0,0.34	,0.34,1.05)
D1=	(1.90875,2.073,2.16006,3.112)
D2=	(2.45918,2.433,2.90435,3.59)
D3=	(3.56987,3.597,3.02376,4.482)
D6=	(3.61446,4.271,3.91377,2.4)
ax4.plot(x4,D0, linestyle='dashed', marker='_', markersize=30, color='orange', linewidth=0.4)
ax4.plot(x4,D1, linestyle='dashed', marker='_', markersize=30, color='blue', linewidth=0.4)
ax4.plot(x4,D2, linestyle='dashed', marker='_', markersize=30, color='black', linewidth=0.4)
ax4.plot(x4,D3, linestyle='dashed', marker='_', markersize=30, color='blue', linewidth=0.4)
#ax4.plot(x4,D4, linestyle='dashed', marker='_', markersize=30, color='red', linewidth=0.4)
ax4.plot(x4,D6, linestyle='dashed', marker='_', markersize=30, color='green', linewidth=0.4)
ax4.set_xticks(x4)
x_labels4 =[r'$\mathrm{D_{0}}$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{BOD}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow\pi_{\mathrm{Ph}}^*)$',r'$\mathrm{D}(\pi_{\mathrm{BOD}} \rightarrow \sigma_{\mathrm{I}}^*)$']
ax4.set_xticklabels(x_labels4, fontsize=12, fontweight='bold', rotation=15)
my_colors4 = ['orange','black','blue',"red"]
for ticklabel, tickcolor in zip(ax4.get_xticklabels(), my_colors2):
    ticklabel.set_color(tickcolor)
ax4.set_xlabel('BOD-Ph'+ r'$\mathbf{NO_2}$'+'(TDA-DFT)_SOS-ωPBEPP86',fontsize=10, fontweight='bold')
ax4.set_ylabel("Energie(eV)",fontweight='bold')
ax4.tick_params(axis='x', rotation=20, color='black')
for x_labels4 in ax4.get_xticklabels():
    x_labels4.set_ha('right')
    x_labels4.set_rotation_mode('anchor')
ax4.set_ylim( -0.2,6)
ax4.set_yticks(np.arange(0, 6, 1))
ax4.tick_params(axis='y', labelsize=9)
# Adjust layout
plt.tight_layout()
# Show or save the figure
plt.savefig('doubletstates2.png', bbox_inches='tight')
plt.show()
